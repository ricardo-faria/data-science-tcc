# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name "Ricardo Faria"
# !git config --global user.email "ricardo.jonas.faria@gmail.com"

# %%
# !git clone https://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@github.com/ricardo-faria/data-science-tcc.git
# Out:
# Cloning into 'data-science-tcc'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 32 (delta 9), reused 27 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 1.90 MiB | 5.03 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
